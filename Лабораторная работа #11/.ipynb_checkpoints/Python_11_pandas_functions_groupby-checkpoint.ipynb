# %% [markdown]
# # Функции в Pandas
# Примеры из презентации

# %%
import pandas as pd

# %%
df = pd.DataFrame({'user_id': [1, 2, 3], 'clicks': [163, 130, 97], 'orders': [2, 4, 0]})
df
# Out:
#    user_id  clicks  orders
# 0        1     163       2
# 1        2     130       4
# 2        3      97       0

# %%
df = pd.DataFrame({'user_id': [1, 2, 3], 'clicks': [163, 130, 97], 'orders': [2, 4, 0], 'calculated': [False, False, True]})
df[['user_id', 'clicks', 'orders', 'calculated']]
# Out:
#    user_id  clicks  orders  calculated
# 0        1     163       2       False
# 1        2     130       4       False
# 2        3      97       0        True

# %%
def watcher(param):
    """Мне только посмотреть"""
    return param == 0

# %%
df['watcher'] = df['orders'].apply(watcher)
df
# Out:
#    user_id  clicks  orders  calculated  watcher
# 0        1     163       2       False    False
# 1        2     130       4       False    False
# 2        3      97       0        True     True

# %% [markdown]
# Применяем метод apply к одному столбцу. Сейчас в переменную функции передаются значения одного столбца

# %%
def conversion(row):
    """Подсчет конверсии переходов в покупки"""
    return row['orders'] / row['clicks']

# %% [markdown]
# ### Как потестировать функцию со значениями одной строки

# %%
row1 = pd.DataFrame({'clicks': [163], 
                     'orders': [2], 
                     'user_id': [1]})
conversion(row1)
# Out:
# 0    0.01227
# dtype: float64

# %% [markdown]
# Применяем метод apply к датафрейму. В переменную функции передаются строки целиком

# %%
df = pd.DataFrame({'user_id': [1, 2, 3], 'clicks': [163, 130, 97], 'orders': [2, 4, 0]})
df[['user_id', 'clicks', 'orders']]
# Out:
#    user_id  clicks  orders
# 0        1     163       2
# 1        2     130       4
# 2        3      97       0

# %%
df['conversion'] = df.apply(conversion, axis=1)

# %%
df[['user_id', 'clicks', 'orders', 'conversion']]
# Out:
#    user_id  clicks  orders  conversion
# 0        1     163       2    0.012270
# 1        2     130       4    0.030769
# 2        3      97       0    0.000000

# %% [markdown]
# ### Анализ рекламных кампаний

# %%
import pandas as pd

# %%
stats = pd.read_excel('ad_campaigns.xlsx')
stats.head()
# Out:
#      Название группы                            Фраза (с минус-словами)  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    Продуктивность  ID объявления                      Заголовок  \
# 0             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 1             4.5     2101704995  МРТ на Менделеевской от 2000₽
# 2             7.4     2101704995  МРТ на Менделеевской от 2000₽
# 3             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4             5.0     2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                Текст  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                               Ссылка
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %%
stats.columns = ['group', 'phrase', 'effect', 'ad_id', 'title', 'text', 'link']
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link
# 0  https://awesome-site.ru/?utm_source=yandex&utm...
# 1  https://awesome-site.ru/?utm_source=yandex&utm...
# 2  https://awesome-site.ru/?utm_source=yandex&utm...
# 3  https://awesome-site.ru/?utm_source=yandex&utm...
# 4  https://awesome-site.ru/?utm_source=yandex&utm...

# %% [markdown]
# ### Lambda-функции
# Хотим посчитать распределение количества слов в столбце с фразами

# %%
phrase = 'МРТ на Менделеевской от 2000'

# %%
len(phrase.split(' '))
# Out:
# 5

# %%
stats['word_count'] = stats['phrase'].apply(lambda word: len(word.split(' ')))
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2

# %%
stats['word_count'] = stats.apply(lambda row: len(row['phrase'].split(' ')), axis = 1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    num_words_in_col_phrase
# 0                        2
# 1                        2
# 2                        6
# 3                        2
# 4                        2

# %% [markdown]
# # вариант с передачей всей строчки функции
# # тут надо обязательно указать параметр axis = 1
#
# stats['word_count'] = stats.apply(lambda x: len(x['phrase'].split(' ')), axis=1)
# stats.head()

# %% [markdown]
# ### Упражнение
# Напишите отдельную функцию word_count, которая считает количество слов в столбце phrase. Функцию можно применять как к столбцу phrase, так и к строке целиком.

# %%
stats['num_words_in_col_phrase'] = stats['phrase'].apply(lambda phrase: len(phrase.split(' ')))

# %%
stats.head(10)
# Out:
#                 group                                             phrase  \
# 0   мрт менделеевская                              "!мрт !менделеевская"
# 1             мрт цао                                "мрт менделеевская"
# 2             мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3             мрт цао                                        "!мрт !цао"
# 4             мрт сао                                          "мрт цао"
# 5             мрт сао       мрт цао -головы -позвоночника -сделать -цена
# 6             мрт сао                                          "мрт сао"
# 7  мрт в москве в сао                                        "!мрт !сао"
# 8  мрт в москве в сао  мрт сао -головы -москве -позвоночника -сделать...
# 9  мрт в москве в сао                                 "мрт в москве сао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 5     7.4  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 6     5.5  2101705000   МРТ в САО от 2000₽. Звоните!
# 7     5.5  2101705000   МРТ в САО от 2000₽. Звоните!
# 8     7.4  2101705000   МРТ в САО от 2000₽. Звоните!
# 9     6.5  2101705001    МРТ в Москве в САО от 2000₽
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
# 5  24 часа. МРТ в день обращения. Консультация вр...
# 6  24 часа. МРТ в день обращения. Консультация вр...
# 7  24 часа. МРТ в день обращения. Консультация вр...
# 8  24 часа. МРТ в день обращения. Консультация вр...
# 9  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 5  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 6  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 7  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 8  https://awesome-site.ru/?utm_source=yandex&utm...           7
# 9  https://awesome-site.ru/?utm_source=yandex&utm...           4
#
#    num_words_in_col_phrase
# 0                        2
# 1                        2
# 2                        6
# 3                        2
# 4                        2
# 5                        6
# 6                        2
# 7                        2
# 8                        7
# 9                        4

# %%
stats['word_count'] = stats.apply(lambda row: len(row['phrase'].split(' ')), axis = 1)
stats.head()

# %% [markdown]
# ### Произвольные функции
# В URL кампаний есть названия. С этим надо что-то делать

# %%
# обращение к индексу и значениям Series
res = stats.word_count.value_counts()
res
# Out:
# 3     1129
# 4      529
# 2      189
# 5      137
# 6       84
# 7       38
# 8       30
# 9       12
# 10       6
# 12       2
# 11       1
# 17       1
# 21       1
# Name: word_count, dtype: int64

# %%
res.index[0]
# Out:
# 3

# %%
res.values[0]
# Out:
# 1129

# %%
# пример ссылки
url = stats.loc[0, 'link']
url
# Out:
# 'https://awesome-site.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}'

# %%
from urllib import parse

# %%
parse.urlsplit('https://ya.ru/news/sport?search=footbal#abc')
# Out:
# SplitResult(scheme='https', netloc='ya.ru', path='/news/sport', query='search=footbal', fragment='abc')

# %%
parsed = parse.urlsplit(url)
parsed
# Out:
# SplitResult(scheme='https', netloc='awesome-site.ru', path='/', query='utm_source=yandex&utm_medium=cpc&utm_campaign=a825749b87&utm_content=dev_{device_type}', fragment='')

# %%
# можно конечно вручную
parsed.query.split('&')[2].split('=')[1]
# Out:
# 'a825749b87'

# %%
# как доставать значения

parsed.netloc

# %%
params = parse.parse_qs(parsed.query)
params
# Out:
# {'utm_source': ['yandex'],
#  'utm_medium': ['cpc'],
#  'utm_campaign': ['a825749b87'],
#  'utm_content': ['dev_{device_type}']}

# %%
# вот и кампании

params['utm_campaign'][0]
# Out:
# 'a825749b87'

# %%
# зачем тут везде списки?

url_with_doubles = 'https://awesome-site.ru/?a=1&a=2&a=3'

parsed = parse.urlsplit(url_with_doubles)
parse.parse_qs(parsed.query)
# Out:
# {'a': ['1', '2', '3']}

# %%
# оборачиваем все в функцию
# в качестве аргумента будет строка датафрейма

def campaign_name(row):
    """Получение названия кампании из ссылки внутри строки row"""

    parsed = parse.urlsplit(row['link'])
    params_dict = parse.parse_qs(parsed.query)

    return params_dict['utm_campaign'][0]

# %%
# проверяем датафрейм
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    num_words_in_col_phrase
# 0                        2
# 1                        2
# 2                        6
# 3                        2
# 4                        2

# %%
stats['campaign'] = stats.apply(campaign_name, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    num_words_in_col_phrase    campaign
# 0                        2  a825749b87
# 1                        2  a825749b87
# 2                        6  a825749b87
# 3                        2  9cc0c5f6ca
# 4                        2  9cc0c5f6ca

# %% [markdown]
# ### Как передать в функцию несколько аргументов

# %%
# как передать несколько аргументов

def power_up(row, n):
    """Возводит значение столбца effect в степень n"""
    return row['effect'] ** n

# %%
stats['power_up'] = stats.apply(power_up, n=3, axis=1)
stats.head()
# Out:
#                group                                             phrase  \
# 0  мрт менделеевская                              "!мрт !менделеевская"
# 1            мрт цао                                "мрт менделеевская"
# 2            мрт цао  мрт менделеевская -головы -позвоночника -сдела...
# 3            мрт цао                                        "!мрт !цао"
# 4            мрт сао                                          "мрт цао"
#
#    effect       ad_id                          title  \
# 0     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 1     4.5  2101704995  МРТ на Менделеевской от 2000₽
# 2     7.4  2101704995  МРТ на Менделеевской от 2000₽
# 3     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
# 4     5.0  2101704999   МРТ в ЦАО от 2000₽. Звоните!
#
#                                                 text  \
# 0  24 часа. МРТ в день обращения. Консультация вр...
# 1  24 часа. МРТ в день обращения. Консультация вр...
# 2  24 часа. МРТ в день обращения. Консультация вр...
# 3  24 часа. МРТ в день обращения. Консультация вр...
# 4  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                 link  word_count  \
# 0  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 2  https://awesome-site.ru/?utm_source=yandex&utm...           6
# 3  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 4  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#    num_words_in_col_phrase    campaign  power_up
# 0                        2  a825749b87    91.125
# 1                        2  a825749b87    91.125
# 2                        6  a825749b87   405.224
# 3                        2  9cc0c5f6ca   125.000
# 4                        2  9cc0c5f6ca   125.000

# %% [markdown]
# ### Упражнение
# В наших данных есть много объявлений с услугой МРТ (в столбце group есть слово 'мрт') круглосуточно (в тексте объявления text есть '24 часа'). Отфильтруйте строки, в которых НЕ упоминается МРТ, но прием идет круглосуточно. Сколько таких строк в датасете?

# %%
def is_not_mrt_24_hrs(row):
    return 'мрт' not in row['group'].split(' ') and '24' in row['text'].split(' ')

# %%
stats['is_not_mrt_24_hrs'] = stats.apply(is_not_mrt_24_hrs, axis = 1)

# %%
stats.query('is_not_mrt_24_hrs == True').head(10)
# Out:
#                         group  \
# 10         цмрт менделеевская
# 11             цмрт стромынка
# 12            цмрт сокольники
# 1570  перово томография центр
# 1571  перово томография центр
# 1572  перово томография центр
# 1573          свао томография
# 1574          свао томография
# 1575          свао томография
# 1576   семеновский томография
#
#                                                  phrase  effect       ad_id  \
# 10                                   мрт в москве в сао     8.5  2101705001
# 11                                "!мрт в !москве !сао"     5.0  2101705001
# 12                                   цмрт менделеевская     3.3  2101705003
# 1570  на мрт щукинский -голова -позвоночника -сделат...     6.6  2428554709
# 1571                     "!на !сиреневом !бульвар !мрт"     1.8  2428554711
# 1572                            перово томография центр     7.7  2428554713
# 1573                       "!перово !томография !центр"     3.3  2428554713
# 1574                          "перово томография центр"     4.8  2428554713
# 1575                                  "свао томография"     3.1  2428554715
# 1576                                "!свао !томография"     3.1  2428554715
#
#                                  title  \
# 10         МРТ в Москве в САО от 2000₽
# 11         МРТ в Москве в САО от 2000₽
# 12     ЦМРТ на Менделеевской. Звоните!
# 1570     МРТ центры в Москве. От 2000₽
# 1571     МРТ центры в Москве. От 2000₽
# 1572     МРТ центры в Москве. От 2000₽
# 1573     МРТ центры в Москве. От 2000₽
# 1574     МРТ центры в Москве. От 2000₽
# 1575  Адреса томографии СВАО. От 2000₽
# 1576  Адреса томографии СВАО. От 2000₽
#
#                                                    text  \
# 10    24 часа. МРТ в день обращения. Консультация вр...
# 11    24 часа. МРТ в день обращения. Консультация вр...
# 12    24 часа. От 2 000₽. Консультация врача бесплат...
# 1570  24 часа. МРТ в день обращения. Консультация вр...
# 1571  24 часа. МРТ в день обращения. Консультация вр...
# 1572  24 часа. МРТ в день обращения. Консультация вр...
# 1573  24 часа. МРТ в день обращения. Консультация вр...
# 1574  24 часа. МРТ в день обращения. Консультация вр...
# 1575  24 часа. МРТ в день обращения. Консультация вр...
# 1576  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                    link  word_count  \
# 10    https://awesome-site.ru/?utm_source=yandex&utm...           5
# 11    https://awesome-site.ru/?utm_source=yandex&utm...           4
# 12    https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1570  https://awesome-site.ru/?utm_source=yandex&utm...           8
# 1571  https://awesome-site.ru/?utm_source=yandex&utm...           4
# 1572  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 1573  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 1574  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 1575  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 1576  https://awesome-site.ru/?utm_source=yandex&utm...           2
#
#       num_words_in_col_phrase    campaign  power_up  is_not_mrt_24_hrs
# 10                          5  27d3cfb133   614.125               True
# 11                          4  27d3cfb133   125.000               True
# 12                          2  f80e902d76    35.937               True
# 1570                        8  8e77a0e565   287.496               True
# 1571                        4  8e77a0e565     5.832               True
# 1572                        3  8e77a0e565   456.533               True
# 1573                        3  8e77a0e565    35.937               True
# 1574                        3  8e77a0e565   110.592               True
# 1575                        2  218404d350    29.791               True
# 1576                        2  218404d350    29.791               True

# %% [markdown]
# # Группировки

# %%
df = pd.DataFrame({'order_id': [1, 2, 3, 4, 5], 'country': ['Россия', 'Китай', 'Китай', 'Россия', 'Россия'], 
                   'category': ['Электроника', 'Авто', 'Электроника', 'Авто', 'Авто'], 
                   'amount': [100, 80, 90, 140, 90]})
df
# Out:
#    order_id country     category  amount
# 0         1  Россия  Электроника     100
# 1         2   Китай         Авто      80
# 2         3   Китай  Электроника      90
# 3         4  Россия         Авто     140
# 4         5  Россия         Авто      90

# %% [markdown]
# Создадим датафрейм df_russia, в котором оставим заказы из России. И аналогично df_china (заказы из Китая).

# %%
df_russia = df.query('country == "Россия"')
df_russia
# Out:
#    order_id country     category  amount
# 0         1  Россия  Электроника     100
# 3         4  Россия         Авто     140
# 4         5  Россия         Авто      90

# %%
df_china = df.query('country == "Китай"')
df_china
# Out:
#    order_id country     category  amount
# 1         2   Китай         Авто      80
# 2         3   Китай  Электроника      90

# %%
df_russia.groupby(['country']).mean()
# Out:
#          order_id  amount
# country
# Россия   3.333333   110.0

# %% [markdown]
# Посчитаем для df_russia и df_china:
# - среднюю стоимость заказа
# - разницу между максимальной и минимальной стоимостью заказа

# %%
df_china.groupby(['country']).mean()
# Out:
#          order_id  amount
# country
# Китай         2.5    85.0

# %%
df_russia.groupby(['country']).max()['amount'] - df_russia.groupby(['country']).min()['amount']
# Out:
# country
# Россия    50
# Name: amount, dtype: int64

# %%
df_china.groupby(['country']).max()['amount'] - df_china.groupby(['country']).min()['amount']
# Out:
# country
# Китай    10
# Name: amount, dtype: int64

# %% [markdown]
# Объединим процесс разбиения на датафреймы

# %%
def groupby_function(data):
    return data.amount.max() - data.amount.min()

# %%
df.groupby('country').apply(groupby_function)
# Out:
# country
# Китай     10
# Россия    50
# dtype: int64

# %% [markdown]
# Вернемся к статистике рекламных кампаний

# %%
# раньше использовали value_counts

stats['campaign'].value_counts().head()
# Out:
# 7f35591a28    456
# 8e77a0e565    348
# 2cc2e7d770    240
# f6d2ae1e3d    220
# e90f4db55a    218
# Name: campaign, dtype: int64

# %%
# более универсальный способ

stats.groupby('campaign').count().head()
# Out:
#             group  phrase  effect  ad_id  title  text  link  word_count  \
# campaign
# 034ada41b6      3       3       3      3      3     3     3           3
# 03fcaecd1d      2       2       2      2      2     2     2           2
# 0697a81555      2       2       2      2      2     2     2           2
# 08cdcb57a3      3       3       3      3      3     3     3           3
# 0f0ba311fb      2       2       2      2      2     2     2           2
#
#             num_words_in_col_phrase  power_up  is_not_mrt_24_hrs
# campaign
# 034ada41b6                        3         3                  3
# 03fcaecd1d                        2         2                  2
# 0697a81555                        2         2                  2
# 08cdcb57a3                        3         3                  3
# 0f0ba311fb                        2         2                  2

# %%
stats.groupby('campaign').count()[['group', 'effect']].head()
# Out:
#             group  effect
# campaign
# 034ada41b6      3       3
# 03fcaecd1d      2       2
# 0697a81555      2       2
# 08cdcb57a3      3       3
# 0f0ba311fb      2       2

# %% [markdown]
# ### Как вернуть столбец из индекса - метод reset_index()

# %%
stats.groupby('campaign').count().reset_index().head()
# Out:
#      campaign  group  phrase  effect  ad_id  title  text  link  word_count  \
# 0  034ada41b6      3       3       3      3      3     3     3           3
# 1  03fcaecd1d      2       2       2      2      2     2     2           2
# 2  0697a81555      2       2       2      2      2     2     2           2
# 3  08cdcb57a3      3       3       3      3      3     3     3           3
# 4  0f0ba311fb      2       2       2      2      2     2     2           2
#
#    num_words_in_col_phrase  power_up  is_not_mrt_24_hrs
# 0                        3         3                  3
# 1                        2         2                  2
# 2                        2         2                  2
# 3                        3         3                  3
# 4                        2         2                  2

# %% [markdown]
# ### К группировке можно применять разные функции такие образом:

# %%
obj = stats.groupby('campaign')

# %%
obj.max().head()
# Out:
#                                      group  \
# campaign
# 034ada41b6           в недорого москва мрт
# 03fcaecd1d       сделать мрт сущевский вал
# 0697a81555  мрт позвоночника сущевский вал
# 08cdcb57a3                         мрт сао
# 0f0ba311fb         сделать мрт октябрьский
#
#                                                        phrase  effect  \
# campaign
# 034ada41b6            в москве открытого типа адрес мрт -цена     9.0
# 03fcaecd1d                              сделать мрт стромынка     6.5
# 0697a81555                         мрт позвоночника стромынка     5.5
# 08cdcb57a3  мрт сао -головы -москве -позвоночника -сделать...     7.4
# 0f0ba311fb                         сделать мрт новослободская     6.4
#
#                  ad_id                              title  \
# campaign
# 034ada41b6  2428554779  Адрес МРТ открытого типа в Москве
# 03fcaecd1d  2101705759     Сделайте МРТ на ул. Стромынка!
# 0697a81555  2101706415  МРТ позвоночника на ул. Стромынка
# 08cdcb57a3  2101705000       МРТ в САО от 2000₽. Звоните!
# 0f0ba311fb  2101705726     Сделайте МРТ на Новослободской
#
#                                                          text  \
# campaign
# 034ada41b6  24 часа. От 2 000₽. Консультация врача бесплат...
# 03fcaecd1d  24 часа. От 2 000₽. Консультация врача бесплат...
# 0697a81555  24 часа. От 2 000₽. Консультация врача бесплат...
# 08cdcb57a3  24 часа. МРТ в день обращения. Консультация вр...
# 0f0ba311fb  24 часа. От 2 000₽. Консультация врача бесплат...
#
#                                                          link  word_count  \
# campaign
# 034ada41b6  https://awesome-site.ru/?utm_source=yandex&utm...           7
# 03fcaecd1d  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 0697a81555  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 08cdcb57a3  https://awesome-site.ru/?utm_source=yandex&utm...           7
# 0f0ba311fb  https://awesome-site.ru/?utm_source=yandex&utm...           3
#
#             num_words_in_col_phrase  power_up  is_not_mrt_24_hrs
# campaign
# 034ada41b6                        7   729.000              False
# 03fcaecd1d                        3   274.625              False
# 0697a81555                        3   166.375              False
# 08cdcb57a3                        7   405.224              False
# 0f0ba311fb                        3   262.144              False

# %%
obj.mean().head()
# Out:
#               effect         ad_id  word_count  num_words_in_col_phrase  \
# campaign
# 034ada41b6  7.200000  2.428555e+09    6.333333                 6.333333
# 03fcaecd1d  5.250000  2.101706e+09    3.000000                 3.000000
# 0697a81555  4.750000  2.101706e+09    3.000000                 3.000000
# 08cdcb57a3  6.133333  2.101705e+09    3.666667                 3.666667
# 0f0ba311fb  5.400000  2.101706e+09    3.000000                 3.000000
#
#               power_up  is_not_mrt_24_hrs
# campaign
# 034ada41b6  470.682000                0.0
# 03fcaecd1d  169.312500                0.0
# 0697a81555  115.187500                0.0
# 08cdcb57a3  245.991333                0.0
# 0f0ba311fb  173.664000                0.0

# %% [markdown]
# Для каждой кампании campaign найдем минимальное значение столбца effect и построим рейтинг кампаний по этим значениям, начиная с самого низкого.

# %%
obj.min().sort_values(by=['effect'])
# Out:
#                                    group  \
# campaign
# 8e77a0e565          1 5 москва мрт тесла
# 7f35591a28                1 градская мрт
# be97523396     мрт в бабушкинском районе
# d96029561c   круглосуточный мрт в москве
# acc3077e55        алтуфьево бибирево мрт
# ...                                  ...
# 9ee3e2c876              11 мрт стромынка
# 28d8dca4df   11 мрт сокольники стромынка
# eb577faed1  мрт на кутузовском проспекте
# d0712ff587        диагностика москва мрт
# 23d6da5a5a                 10 мрт палиха
#
#                                           phrase  effect       ad_id  \
# campaign
# 8e77a0e565                "!1 !мрт !нагатинский"     1.6  2101705401
# 7f35591a28                   "!1 !градская !мрт"     1.7  2101705009
# be97523396  "!мрт !в !москве !метро !щелковская"     1.8  2101705493
# d96029561c     "!круглосуточный !мрт !в !москве"     1.8  2428555742
# acc3077e55           "!алтуфьево !бибирево !мрт"     1.9  2428554791
# ...                                          ...     ...         ...
# 9ee3e2c876                 "!11 !мрт !стромынка"     7.7  3826704855
# 28d8dca4df     "!11 !мрт !сокольники !стромынка"     8.4  2428554835
# eb577faed1     мрт центр москва -диагностическая     8.5  3401169402
# d0712ff587           "!диагностика !москва !мрт"     8.7  2428554887
# 23d6da5a5a               "!клиника !москва !мрт"     8.7  3826704862
#
#                                         title  \
# campaign
# 8e77a0e565      МРТ центры в Москве. От 2000₽
# 7f35591a28    МРТ в Москве от 2000₽. Звоните!
# be97523396      МРТ у метро в Москве от 2000₽
# d96029561c        МРТ круглосуточно. От 2000₽
# acc3077e55      Томография в Москве. От 2000₽
# ...                                       ...
# 9ee3e2c876      МРТ на ул. Стромынка от 2000₽
# 28d8dca4df   МРТ на Стромынке, 11. Сокольники
# eb577faed1    Центры МРТ в Москве – от 2 000₽
# d0712ff587  Диагностика МРТ в Москве. От 2000
# 23d6da5a5a     Клиники МРТ в Москве. От 2000₽
#
#                                                          text  \
# campaign
# 8e77a0e565  24 часа. МРТ в день обращения. Консультация вр...
# 7f35591a28  24 часа. МРТ в день обращения. Консультация вр...
# be97523396  24 часа. МРТ в день обращения. Консультация вр...
# d96029561c  24 часа. МРТ в день обращения. Консультация вр...
# acc3077e55  24 часа. МРТ в день обращения. Консультация вр...
# ...                                                       ...
# 9ee3e2c876  24 часа. МРТ в день обращения. Консультация вр...
# 28d8dca4df  24 часа. От 2 000₽. Консультация врача бесплат...
# eb577faed1  24 часа. МРТ в день обращения. Консультация вр...
# d0712ff587  24 часа. МРТ в день обращения. Консультация вр...
# 23d6da5a5a  24 часа. МРТ в день обращения. Консультация вр...
#
#                                                          link  word_count  \
# campaign
# 8e77a0e565  https://awesome-site.ru/?utm_source=yandex&utm...           2
# 7f35591a28  https://awesome-site.ru/?utm_source=yandex&utm...           2
# be97523396  https://awesome-site.ru/?utm_source=yandex&utm...           3
# d96029561c  https://awesome-site.ru/?utm_source=yandex&utm...           3
# acc3077e55  https://awesome-site.ru/?utm_source=yandex&utm...           2
# ...                                                       ...         ...
# 9ee3e2c876  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 28d8dca4df  https://awesome-site.ru/?utm_source=yandex&utm...           4
# eb577faed1  https://awesome-site.ru/?utm_source=yandex&utm...           4
# d0712ff587  https://awesome-site.ru/?utm_source=yandex&utm...           3
# 23d6da5a5a  https://awesome-site.ru/?utm_source=yandex&utm...           3
#
#             num_words_in_col_phrase  power_up  is_not_mrt_24_hrs
# campaign
# 8e77a0e565                        2     4.096              False
# 7f35591a28                        2     4.913              False
# be97523396                        3     5.832              False
# d96029561c                        3     5.832              False
# acc3077e55                        2     6.859              False
# ...                             ...       ...                ...
# 9ee3e2c876                        3   456.533              False
# 28d8dca4df                        4   592.704              False
# eb577faed1                        4   614.125              False
# d0712ff587                        3   658.503              False
# 23d6da5a5a                        3   658.503              False
#
# [115 rows x 11 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13736/1799003922.py in <module>
# ----> 1 obj.sort_values(by=['effect'])
#
# C:\Python310\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %% [markdown]
# ### Несколько функций в группировках

# %%
# задаем несколько функций сразу

stats.groupby('campaign').agg(['min', 'max'])['effect'].head()

# %%
# разные метрики для разных столбцов

results = stats.groupby('campaign').agg({'effect': ['min', 'max'], 'power_up': 'mean'})
results.head()

# %% [markdown]
# ### Как обращаться к вложенным столбцам

# %%
results['effect']['max'].head()

# %%
# или даже так
stats.groupby('campaign').agg({'effect': ['min', 'max'], 'power_up': 'mean'})['effect']['max'].head()

# %%
# группировка по нескольким столбцам

stats.groupby(['group', 'campaign']).count().head()

# %%
# максимальное число объявлений в одной группе

stats.groupby(['group', 'campaign']).count().sort_values('phrase', ascending=False).head()
